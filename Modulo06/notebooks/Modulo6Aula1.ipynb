# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %matplotlib notebook

# %%
df = pd.read_csv('DadosNascimento.csv')
plt.plot(df['QTDFILVIVO'].value_counts())
# Out:
# <img src="data:image/png;base64,..." width="640">
