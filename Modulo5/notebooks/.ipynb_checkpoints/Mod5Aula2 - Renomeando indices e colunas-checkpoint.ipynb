# %% [markdown]
# # Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Construindo um dataframe](#read)
# 3. [Renomeando colunas](#colunas)
# 4. [Renomeando índices](#indices)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# # 2. Construindo um dataframe <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.DataFrame(
    np.random.randn(9, 4)*100,
    index=["A", "B", "C", "D", "E", "F", "G", "H", "I"],
    columns=["coluna1", "coluna2", "coluna3","coluna4"],
)
df
# Out:
#       coluna1     coluna2     coluna3     coluna4
# A   -5.246791  -59.818862   72.089872  -97.971357
# B -159.799586   78.488307 -102.455616 -189.027206
# C  -41.234567 -123.425139  -55.626813    1.849032
# D  130.646404    5.669037  -24.562078  -42.961498
# E  -55.402580  -85.159296   24.396384 -131.664489
# F   60.318084  -78.258235  134.679513 -185.986488
# G  -98.663994   64.289361   61.928901 -204.545004
# H   -4.038162   51.103090   34.712628   -6.792411
# I  -57.462649 -282.572348 -133.700463  274.313958

# %% [markdown]
# # 3. Renomeando colunas <a name="colunas"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df.columns
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4'], dtype='object')

# %%
df.columns = ['segunda', 'terça', 'quarta', 'quinta']

# %%
df.columns
# Out:
# Index(['segunda', 'terça', 'quarta', 'quinta'], dtype='object')

# %%
df
# Out:
#       segunda       terça      quarta      quinta
# A   -5.246791  -59.818862   72.089872  -97.971357
# B -159.799586   78.488307 -102.455616 -189.027206
# C  -41.234567 -123.425139  -55.626813    1.849032
# D  130.646404    5.669037  -24.562078  -42.961498
# E  -55.402580  -85.159296   24.396384 -131.664489
# F   60.318084  -78.258235  134.679513 -185.986488
# G  -98.663994   64.289361   61.928901 -204.545004
# H   -4.038162   51.103090   34.712628   -6.792411
# I  -57.462649 -282.572348 -133.700463  274.313958

# %% [markdown]
# # 4. Renomeando índices <a name="indices"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df['coluna5'] = ['letraA','letraB','letraC','letraD','letraE','letraF','letraG','letraH','letraI']

# %%
df
# Out:
#       coluna1     coluna2     coluna3     coluna4  coluna5
# A  -30.684273  199.404229  -63.364616  211.101027        1
# B -156.633279   64.825083  -21.820454  -50.548766        2
# C   13.621897 -197.201610  -69.126469  -98.274231        3
# D  -90.425057  129.075907  -81.697673    7.077724        4
# E   43.193075  133.412986 -224.265676   51.648934        5
# F  -66.227071   40.726831   22.456496  146.381149        6
# G   30.163603  -50.311824  -25.594538   99.418164        7
# H  -89.576367   94.267785   67.550308  -72.148525        8
# I   23.159873  -32.992297  -31.562883    1.946960        9

# %%
df.set_index('coluna5')
# Out:
#             coluna1     coluna2     coluna3     coluna4
# coluna5
# 1        -30.684273  199.404229  -63.364616  211.101027
# 2       -156.633279   64.825083  -21.820454  -50.548766
# 3         13.621897 -197.201610  -69.126469  -98.274231
# 4        -90.425057  129.075907  -81.697673    7.077724
# 5         43.193075  133.412986 -224.265676   51.648934
# 6        -66.227071   40.726831   22.456496  146.381149
# 7         30.163603  -50.311824  -25.594538   99.418164
# 8        -89.576367   94.267785   67.550308  -72.148525
# 9         23.159873  -32.992297  -31.562883    1.946960

# %%
df
# Out:
#       coluna1     coluna2     coluna3     coluna4  coluna5
# A  -30.684273  199.404229  -63.364616  211.101027        1
# B -156.633279   64.825083  -21.820454  -50.548766        2
# C   13.621897 -197.201610  -69.126469  -98.274231        3
# D  -90.425057  129.075907  -81.697673    7.077724        4
# E   43.193075  133.412986 -224.265676   51.648934        5
# F  -66.227071   40.726831   22.456496  146.381149        6
# G   30.163603  -50.311824  -25.594538   99.418164        7
# H  -89.576367   94.267785   67.550308  -72.148525        8
# I   23.159873  -32.992297  -31.562883    1.946960        9

# %%
df.reset_index()
# Out:
#   index     coluna1     coluna2     coluna3     coluna4  coluna5
# 0     A  -30.684273  199.404229  -63.364616  211.101027        1
# 1     B -156.633279   64.825083  -21.820454  -50.548766        2
# 2     C   13.621897 -197.201610  -69.126469  -98.274231        3
# 3     D  -90.425057  129.075907  -81.697673    7.077724        4
# 4     E   43.193075  133.412986 -224.265676   51.648934        5
# 5     F  -66.227071   40.726831   22.456496  146.381149        6
# 6     G   30.163603  -50.311824  -25.594538   99.418164        7
# 7     H  -89.576367   94.267785   67.550308  -72.148525        8
# 8     I   23.159873  -32.992297  -31.562883    1.946960        9

# %%
df.reset_index(drop=True)
# Out:
#       coluna1     coluna2     coluna3     coluna4  coluna5
# 0  -30.684273  199.404229  -63.364616  211.101027        1
# 1 -156.633279   64.825083  -21.820454  -50.548766        2
# 2   13.621897 -197.201610  -69.126469  -98.274231        3
# 3  -90.425057  129.075907  -81.697673    7.077724        4
# 4   43.193075  133.412986 -224.265676   51.648934        5
# 5  -66.227071   40.726831   22.456496  146.381149        6
# 6   30.163603  -50.311824  -25.594538   99.418164        7
# 7  -89.576367   94.267785   67.550308  -72.148525        8
# 8   23.159873  -32.992297  -31.562883    1.946960        9
